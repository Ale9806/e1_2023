# %%
import  sys 
sys.path.append('..')
from data import dataset 
import matplotlib.pyplot as plt

# %%
pixel_test_dataset = dataset.PixelTextDataset(image_size=512 ,font ="arial.ttf")
for data_point in pixel_test_dataset:
    break
# Out:
# Using custom data configuration lambdalabs--pokemon-blip-captions-10e3527a764857bd
# Reusing dataset parquet (C:\Users\aleja\.cache\huggingface\datasets\lambdalabs___parquet\lambdalabs--pokemon-blip-captions-10e3527a764857bd\0.0.0\2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec)

# %%
plt.imshow(data_point['image'])
plt.title(data_point['text'])
plt.show(   )
